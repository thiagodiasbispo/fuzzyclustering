# %% [markdown]
# ## Lendos os dados normalizados previamente

# %%
import os
import numpy as np
from IPython.display import display
import pandas as pd

DATA_BASE_PATH = "/content/drive/My Drive/Fuzzy Clustering/data"

FAC_FILE = os.path.join(DATA_BASE_PATH, "mfeat-fac-norm.npy")
FOU_FILE = os.path.join(DATA_BASE_PATH, "mfeat-fou-norm.npy")
KAR_FILE = os.path.join(DATA_BASE_PATH, "mfeat-kar-norm.npy")

fac_norm = np.load(FAC_FILE)
fou_norm = np.load(FOU_FILE)
kar_norm = np.load(KAR_FILE)

print("FAC Normalized")
display(pd.DataFrame(fac_norm).head(2))

print("FOU Normalized")
display(pd.DataFrame(fou_norm).head(2))

print("KAR Normalized")
display(pd.DataFrame(kar_norm).head(2))
# Out:
# FAC Normalized
#         0         1         2    ...       213       214       215
# 0  0.069196  0.320248  0.040576  ...  0.785714  0.500000  0.565217
# 1  0.120536  0.231405  0.140052  ...  0.642857  0.714286  0.478261
#
# [2 rows x 216 columns]
# FOU Normalized
#          0         1         2   ...        73        74        75
# 0  0.155955  0.247037  0.148847  ...  0.628352  0.095886  0.588917
# 1  0.113125  0.219041  0.151407  ...  0.711892  0.162660  0.604874
#
# [2 rows x 76 columns]
# KAR Normalized
#          0         1         2   ...        61        62        63
# 0  0.191173  0.128265  0.889728  ...  0.836661  0.219735  0.433051
# 1  0.354385  0.089040  0.498033  ...  0.618422  0.565718  0.595312
#
# [2 rows x 64 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Computando as matrizes de dissimilaridade

# %%
from sklearn.metrics.pairwise import euclidean_distances

fac_dissimilarity = euclidean_distances(fac_norm, fac_norm)
fou_dissimilarity = euclidean_distances(fou_norm, fou_norm)
kar_dissimilarity = euclidean_distances(kar_norm, kar_norm)

print("FAC Dissimilarity  shape: ", fac_dissimilarity.shape)
pd.DataFrame(fac_dissimilarity).head(3)
# Out:
# FAC Dissimilarity  shape:  (2000, 2000)
#        0         1         2     ...      1997      1998      1999
# 0  0.000000  1.725886  1.869928  ...  4.040457  3.805022  4.600745
# 1  1.725886  0.000000  1.571679  ...  3.680461  3.236586  4.153686
# 2  1.869928  1.571679  0.000000  ...  3.969217  3.423565  4.545220
#
# [3 rows x 2000 columns]

# %%
print("FOU Dissimilarity shape: ", fou_dissimilarity.shape)
pd.DataFrame(fou_dissimilarity).head(3)
# Out:
# FOU Dissimilarity shape:  (2000, 2000)
#        0         1         2     ...      1997      1998      1999
# 0  0.000000  1.353952  1.308675  ...  2.243905  1.966262  2.135231
# 1  1.353952  0.000000  0.989246  ...  2.653470  2.302680  2.427257
# 2  1.308675  0.989246  0.000000  ...  2.584899  2.295063  2.339336
#
# [3 rows x 2000 columns]

# %%
print("KAR Dissimilarity shape: ", kar_dissimilarity.shape)
pd.DataFrame(kar_dissimilarity).head(3)
# Out:
# KAR Dissimilarity shape:  (2000, 2000)
#        0         1         2     ...      1997      1998      1999
# 0  0.000000  1.270193  1.397034  ...  1.605476  1.375733  1.655586
# 1  1.270193  0.000000  1.470758  ...  1.616383  1.314507  1.666247
# 2  1.397034  1.470758  0.000000  ...  1.495470  1.353730  1.698088
#
# [3 rows x 2000 columns]

# %% [markdown]
# ## Exportando matrizes de dissimilaridades

# %% [markdown]
# # Nova seção

# %%
np.save(FAC_FILE.replace("norm.npy","dissimilarity"), fac_dissimilarity)
np.save(FOU_FILE.replace("norm.npy","dissimilarity"), fou_dissimilarity)
np.save(KAR_FILE.replace("norm.npy","dissimilarity"), kar_dissimilarity)
